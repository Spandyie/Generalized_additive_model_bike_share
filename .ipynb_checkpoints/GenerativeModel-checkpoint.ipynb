# %%
from pygam import LinearGAM
import pandas as pd
import torch as t
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
day_data = pd.read_csv("day.csv")

# %%
feature =['cnt','season','windspeed','atemp','hum','yr','mnth']
Daily_bike_share= pd.DataFrame()
Daily_bike_share = day_data[feature]

# %%
Daily_bike_share.head(10)
# Out:
#     cnt  season  windspeed     atemp       hum  yr  mnth
# 0   985       1   0.160446  0.363625  0.805833   0     1
# 1   801       1   0.248539  0.353739  0.696087   0     1
# 2  1349       1   0.248309  0.189405  0.437273   0     1
# 3  1562       1   0.160296  0.212122  0.590435   0     1
# 4  1600       1   0.186900  0.229270  0.436957   0     1
# 5  1606       1   0.089565  0.233209  0.518261   0     1
# 6  1510       1   0.168726  0.208839  0.498696   0     1
# 7   959       1   0.266804  0.162254  0.535833   0     1
# 8   822       1   0.361950  0.116175  0.434167   0     1
# 9  1321       1   0.223267  0.150888  0.482917   0     1

# %% [markdown]
# The correlation between the variables to be used for the Generative Additive Model can been in the figure below.

# %%
correlation = Daily_bike_share.corr()
correlation.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col0 {
#             background-color:  #023858;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col1 {
#             background-color:  #6ba5cd;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col2 {
#             background-color:  #fef6fa;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col3 {
#             background-color:  #1c7fb8;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col4 {
#             background-color:  #ede8f3;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col5 {
#             background-color:  #3d93c2;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col6 {
#             background-color:  #9ab8d8;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col0 {
#             background-color:  #6ba5cd;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col1 {
#             background-color:  #023858;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col2 {
#             background-color:  #fdf5fa;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col3 {
#             background-color:  #8bb2d4;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col4 {
#             background-color:  #a9bfdc;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col5 {
#             background-color:  #f0eaf4;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col6 {
#             background-color:  #045c90;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row2_col0 {
#             background-color:  #fff7fb;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row2_col1 {
#             background-color:  #fff7fb;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row2_col2 {
#             background-color:  #023858;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row2_col3 {
#             background-color:  #fff7fb;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row2_col4 {
#             background-color:  #fff7fb;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row2_col5 {
#             background-color:  #f2ecf5;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row2_col6 {
#             background-color:  #fff7fb;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row3_col0 {
#             background-color:  #187cb6;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row3_col1 {
#             background-color:  #81aed2;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row3_col2 {
#             background-color:  #f7f0f7;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row3_col3 {
#             background-color:  #023858;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row3_col4 {
#             background-color:  #bcc7e1;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row3_col5 {
#             background-color:  #e8e4f0;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row3_col6 {
#             background-color:  #abbfdc;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row4_col0 {
#             background-color:  #efe9f3;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row4_col1 {
#             background-color:  #adc1dd;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row4_col2 {
#             background-color:  #fff7fb;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row4_col3 {
#             background-color:  #c9cee4;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row4_col4 {
#             background-color:  #023858;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row4_col5 {
#             background-color:  #fff7fb;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row4_col6 {
#             background-color:  #acc0dd;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row5_col0 {
#             background-color:  #2c89bd;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row5_col1 {
#             background-color:  #dfddec;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row5_col2 {
#             background-color:  #dedcec;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row5_col3 {
#             background-color:  #dddbec;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row5_col4 {
#             background-color:  #eee9f3;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row5_col5 {
#             background-color:  #023858;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row5_col6 {
#             background-color:  #e2dfee;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row6_col0 {
#             background-color:  #96b6d7;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row6_col1 {
#             background-color:  #045c90;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row6_col2 {
#             background-color:  #faf3f9;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row6_col3 {
#             background-color:  #b0c2de;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row6_col4 {
#             background-color:  #a5bddb;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row6_col5 {
#             background-color:  #f0eaf4;
#         }    #T_c618fc80_ab45_11e8_aba0_08d40c8180f8row6_col6 {
#             background-color:  #023858;
#         }</style>
# <table id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >cnt</th>
#         <th class="col_heading level0 col1" >season</th>
#         <th class="col_heading level0 col2" >windspeed</th>
#         <th class="col_heading level0 col3" >atemp</th>
#         <th class="col_heading level0 col4" >hum</th>
#         <th class="col_heading level0 col5" >yr</th>
#         <th class="col_heading level0 col6" >mnth</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8level0_row0" class="row_heading level0 row0" >cnt</th>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col0" class="data row0 col0" >1</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col1" class="data row0 col1" >0.4061</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col2" class="data row0 col2" >-0.234545</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col3" class="data row0 col3" >0.631066</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col4" class="data row0 col4" >-0.100659</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col5" class="data row0 col5" >0.56671</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row0_col6" class="data row0 col6" >0.279977</td>
#     </tr>    <tr>
#         <th id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8level0_row1" class="row_heading level0 row1" >season</th>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col0" class="data row1 col0" >0.4061</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col1" class="data row1 col1" >1</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col2" class="data row1 col2" >-0.229046</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col3" class="data row1 col3" >0.342876</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col4" class="data row1 col4" >0.205445</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col5" class="data row1 col5" >-0.00184434</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row1_col6" class="data row1 col6" >0.83144</td>
#     </tr>    <tr>
#         <th id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8level0_row2" class="row_heading level0 row2" >windspeed</th>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row2_col0" class="data row2 col0" >-0.234545</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row2_col1" class="data row2 col1" >-0.229046</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row2_col2" class="data row2 col2" >1</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row2_col3" class="data row2 col3" >-0.183643</td>
#         <td id="T_c618fc80_ab45_11e8_aba0_08d40c8180f8row2_col4" class="data row2 col4" >-0.

# %%
Train_data, test_data = train_test_split(Daily_bike_share, test_size = 0.2)

X_train = Train_data.drop(columns = ["cnt"])
y_train = Train_data[['cnt']]
########################################
X_test = test_data.drop(columns = ["cnt"])
y_test = test_data[['cnt']]

# %%
gam = LinearGAM(n_splines=10).gridsearch(X_train, y_train)
# Out:
# 100% (11 of 11) |########################| Elapsed Time: 0:00:00 Time:  0:00:00

# %%
XX = gam.generate_X_grid()

fig, axs = plt.subplots(1,6, figsize=(20,4))

titles = feature[1:]

for i, ax in enumerate(axs):
    pdep, confi = gam.partial_dependence(XX, feature=i, width=.95)
    ax.plot(XX[:, i], pdep)
    ax.plot(XX[:, i], *confi, c='r', ls='--')
    ax.set_title(titles[i])

# %%
gam.summary()
# Out:
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                     24.3666
# Link Function:                     IdentityLink Log Likelihood:                                 -8240.5115
# Number of Samples:                          584 AIC:                                            16531.7562
#                                                 AICc:                                            16534.155
#                                                 GCV:                                           579130.5874
#                                                 Scale:                                         535804.7201
#                                                 Pseudo R-Squared:                                   0.8634
# ==========================================================================================================
# Feature Function   Data Type      Num Splines   Spline Order  Linear Fit  Lambda     P > x      Sig. Code
# ================== ============== ============= ============= =========== ========== ========== ==========
# feature 1          numerical      10            3             False       1.0        5.36e-11   ***
# feature 2          numerical      10            3             False       1.0        1.70e-12   ***
# feature 3          numerical      10            3             False       1.0        1.11e-16   ***
# feature 4          numerical      10            3             False       1.0        1.11e-16   ***
# feature 5          categorical    2             0             False       1.0        1.11e-16   ***
# feature 6          numerical      10            3             False       1.0        1.49e-02   *
# intercept                                                                            1.11e-16   ***
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.

# %%
plt.plot(gam.predict(XX), 'r--')
plt.plot(gam.prediction_intervals(XX, width=.95), color='b', ls='--')

#plt.plot(y_train, facecolor='gray', edgecolors='none')
plt.title('95% prediction interval')
# Out:
# Text(0.5,1,'95% prediction interval')

# %%
plt.plot(y_test, gam.predict(X_test),"*")
plt.xlabel("Predicted Value")
plt.ylabel("Actual value")
# Out:
# Text(0,0.5,'Actual value')

# %%
from sklearn.metrics import mean_absolute_error,r2_score
print("Mean absolute error >> " + str(mean_absolute_error(y_test, gam.predict(X_test))))
print("Coefficient of determination >> " + str(r2_score(y_test, gam.predict(X_test))))
# Out:
# Mean absolute error >> 478.76158826171985
# Coefficient of determination >> 0.8933458756354504
